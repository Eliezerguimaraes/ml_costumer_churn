# %% [markdown]
# <a href="https://colab.research.google.com/github/Eliezerguimaraes/ml_costumer_churn/blob/main/Minera%C3%A7%C3%A3o_de_Dados_COSTOMERCHURN_17_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Eliezerguimaraes/ml_costumer_churn/main/Customer-Churn.csv'

dados = pd.read_csv(url)
dados.head()
# Out:
#    Maior65Anos Conjuge Dependentes  MesesDeContrato TelefoneFixo  \
# 0            0     Sim         Nao                1          Nao
# 1            0     Nao         Nao               34          Sim
# 2            0     Nao         Nao                2          Sim
# 3            0     Nao         Nao               45          Nao
# 4            0     Nao         Nao                2          Sim
#
#   VariasLinhasTelefonicas ServicoDeInternet SegurancaOnline BackupOnline  \
# 0    SemServicoTelefonico               DSL             Nao          Sim
# 1                     Nao               DSL             Sim          Nao
# 2                     Nao               DSL             Sim          Sim
# 3    SemServicoTelefonico               DSL             Sim          Nao
# 4                     Nao       FibraOptica             Nao          Nao
#
#   SeguroNoDispositivo SuporteTecnico TVaCabo StreamingDeFilmes TipoDeContrato  \
# ...

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


x = dados[['Maior65Anos', 'Conjuge', 'Dependentes', 'MesesDeContrato',
           'TelefoneFixo', 'VariasLinhasTelefonicas', 'ServicoDeInternet',
           'SegurancaOnline', 'BackupOnline', 'ProtecaoDispositivo',
           'SuporteTecnico', 'StreamingTV', 'StreamingFilmes',
           'Contrato', 'FaturaDigital', 'FormaDePagamento', 'ContaMensal']]
y = dados['Churn']

seed = 20
treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, random_state=seed, test_size = 0.25, stratify=y)

print("Treinaremos com %d elementos e testaremos com %d elementos" %(len(treino_x), len (teste_x)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-3daa01bbb99c> in <cell line: 6>()
#       4
#       5
# ----> 6 x = dados[['Maior65Anos', 'Conjuge', 'Dependentes', 'MesesDeContrato',
#       7            'TelefoneFixo', 'VariasLinhasTelefonicas', 'ServicoDeInternet',
#       8            'SegurancaOnline', 'BackupOnline',  # Removed 'ProtecaoDispositivo'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %% [markdown]
# ##MEU CLASSIFICADOR

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

modelo = LinearSVC() #Cria modelo
modelo.fit(treino_x, treino_y) #Treina
previsoes = modelo.predict(teste_x) #Teste

acuracia = accuracy_score(teste_y, previsoes) * 100
print("A acuracia foi %.2f%%" %acuracia)
# Out:
# A acuracia foi 52.04%
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# ##DUMMY

# %%
from sklearn.dummy import DummyClassifier

dummy_stratified = DummyClassifier() #cria modelo
dummy_stratified.fit(treino_x, treino_y) #treina modelo
acuracia = dummy_stratified.score(teste_x, teste_y) * 100 #teste

print("A acuracia do dummy stratified foi %.2f%%" %acuracia)
# Out:
# A acuracia do dummy stratified foi 52.59%
